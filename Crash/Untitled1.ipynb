# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/arthurspriet/Desktop/GORGIAS.csv')

# %%
data
# Out:
#     contact_id  associated_company_id first_name   last_name  \
# 0    160476203              732746302   Jennifer      Swieca
# 1    104336537              732745962       Greg   Shewchuck
# 2    139304105              732745962        Amy       Klein
# 3      2520414              732745962     Ashley  Dombkowski
# 4    104316700              732745962   Julianna     Doherty
# 5         6453              732745348       Jeff      Martin
# 6        13426              732745348        Jen         Tbd
# 7        13127              732745348     Teresa        Tsou
# 8    104322248              732745962        Ben   Thomander
# 9     11460202              732745962      Chris      Cornyn
# 10   139306208              732745962      Chris      Cornyn
# 11    30796352              732746302    Martina     Biselli
# 12     8284924              732745962     Justin     Michaud
# 13    30796252              732746302    Natasha      Yadgar
# ...

# %%
data.dtypes
# Out:
# contact_id                 int64
# associated_company_id      int64
# first_name                object
# last_name                 object
# email                     object
# linkedin_profile          object
# contact_last_contacted    object
# contact_score              int64
# persona                   object
# dtype: object
