# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib
from urllib.request import Request, urlopen
import re
import time
import requests

# %%
url = 'https://karman-skin.com'

# %%
r = requests.get(url,)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
r.text
# Out:
# '<!doctype html>\n<html class="supports-no-js" lang="fr">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n  <meta name="viewport" content="width=device-width,initial-scale=1">\n  <meta name="theme-color" content="">\n  <link rel="canonical" href="https://karman-skin.com/">\n\n  \n    <link rel="shortcut icon" href="//cdn.shopify.com/s/files/1/0510/6221/0742/files/Favicon_32x32.png?v=1619098521" type="image/png" />\n  \n\n  <title>\n  Karman\n  </title>\n\n  \n\n  <!-- /snippets/social-meta-tags.liquid -->\n\n\n\n\n<meta property="og:site_name" content="Karman">\n<meta property="og:url" content="https://karman-skin.com/">\n<meta property="og:title" content="Karman">\n<meta property="og:type" content="website">\n<meta property="og:description" content="Karman">\n\n\n\n\n\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:title" content="Karman">\n<meta name="twitter:description" content="Karman">\n\n\n  <s
# ...

# %%
type(r.text)
# Out:
# str

# %%
s = str(r.text)

# %%
s.find('shopify')
# Out:
# 365

# %%
url2 = 'https://www.ironhack.com/en?utm_campaign=RMTEU_France_Global_Search_Brand_EN&utm_source=google&utm_medium=cpc&utm_content=search-brand&utm_term=ironhack&gclid=CjwKCAiAyPyQBhB6EiwAFUuaknb0U0L_3vBOeusjjghx7qTmSiOyY40gvM0rA8sUmXpgW35bXWe2nhoCnl0QAvD_BwE'
r2 = requests.get(url2)
soup = BeautifulSoup(r2.content, 'html.parser')
t = str(r2.text)

# %%
t.find('shopify')
# Out:
# -1

# %%
creator_id ='1641228307'
